# %% [markdown]
# # 01_Functions.ipynb

# %% [markdown]
# ## Question 1
# Create a function that returns the square of a number.

# %%
def sqr(x: int) -> int:
    return x * x
sqr(4)
# Out:
# 16

# %% [markdown]
# ## Question 2
# Create a function that takes name and age and returns formatted output.

# %%
# Your solution here

# %% [markdown]
# ## Question 3
# Create a function that returns the largest of two numbers.

# %%
# Your solution here

# %% [markdown]
# ## Question 4
# Create a function with a default argument so greet() returns 'Hello Guest'.

# %%
# Your solution here

# %% [markdown]
# ## Question 5
# Difference between print() and return().

# %%
# Your solution here
