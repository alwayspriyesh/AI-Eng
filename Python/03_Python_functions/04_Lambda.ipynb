# %% [markdown]
# # 04_Lambda.ipynb

# %% [markdown]
# ## Question 1
# Lambda for addition.

# %%
# Your solution here

# %% [markdown]
# ## Question 2
# Lambda for square.

# %%
# Your solution here

# %% [markdown]
# ## Question 3
# Lambda to check even number.

# %%
# Your solution here

# %% [markdown]
# ## Question 4
# Sort words by length using lambda.

# %%
# Your solution here

# %% [markdown]
# ## Question 5
# One advantage of lambda.

# %%
# Your solution here
