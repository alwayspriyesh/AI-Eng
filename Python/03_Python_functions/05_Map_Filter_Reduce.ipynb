# %% [markdown]
# # 05_Map_Filter_Reduce.ipynb

# %% [markdown]
# ## Question 1
# Use map to square numbers.

# %%
# Your solution here

# %% [markdown]
# ## Question 2
# Use map to convert strings to integers.

# %%
# Your solution here

# %% [markdown]
# ## Question 3
# Use filter to keep even numbers.

# %%
# Your solution here

# %% [markdown]
# ## Question 4
# Use reduce to calculate sum.

# %%
# Your solution here

# %% [markdown]
# ## Question 5
# Explain map, filter and reduce.

# %%
# Your solution here
