# %% [markdown]
# # 02_Args_Kwargs.ipynb

# %% [markdown]
# ## Question 1
# Use *args to sum numbers.

# %%
# Your solution here

# %% [markdown]
# ## Question 2
# Use *args to find largest number.

# %%
# Your solution here

# %% [markdown]
# ## Question 3
# Use **kwargs to print name, age, city.

# %%
# Your solution here

# %% [markdown]
# ## Question 4
# When would you use *args?

# %%
# Your solution here

# %% [markdown]
# ## Question 5
# When would you use **kwargs?

# %%
# Your solution here
