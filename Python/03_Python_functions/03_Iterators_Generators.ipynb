# %% [markdown]
# # 03_Iterators_Generators.ipynb

# %% [markdown]
# ## Question 1
# Create iterator from [10,20,30] and print first element.

# %%
# Your solution here

# %% [markdown]
# ## Question 2
# Print remaining elements using next().

# %%
# Your solution here

# %% [markdown]
# ## Question 3
# Generator yielding 1 to 5.

# %%
# Your solution here

# %% [markdown]
# ## Question 4
# Generator yielding squares from 1 to 5.

# %%
# Your solution here

# %% [markdown]
# ## Question 5
# Why are generators memory efficient?

# %%
# Your solution here
