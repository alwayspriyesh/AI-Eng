# %% [markdown]
# # Day2_Lists_Assessment.ipynb
#
# Solve each question below.

# %% [markdown]
# ## Question 1
# Create a list of 5 numbers and print the largest and smallest values.

# %%
list1:list=[2,3,5,7,11]
print(max(list), min(list))
# Out:
# 69 2

# %% [markdown]
# ## Question 2
# Add an element using append() and another using insert().

# %%
list1.append(19)
list1.insert(0,69)
list1
# Out:
# [69, 2, 3, 5, 7, 11, 19]

# %% [markdown]
# ## Question 3
# Remove duplicate values from a list.

# %%
list2 = [2,3,5,56,35,4,3,3,2,3, 65,56]
list3 = []
for x in list2:
    if x in list3:
        pass
    else:
        list3.append(x)

list3
# Out:
# [2, 3, 5, 56, 35, 4, 65]

# %% [markdown]
# ## Question 4
# Find the sum and average of all elements in a list.

# %%
sumation = sum(list1)
avg = (sumation/len(list1))

print(sumation)
print( avg)
# Out:
# 116
# 16.571428571428573

# %% [markdown]
# ## Question 5
# Create a list comprehension that stores squares of numbers from 1 to 10.

# %%
nums:list = [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
sqr:list = []
for x in nums:
    x**= 2
    sqr.append(x)

sqr
# Out:
# [1, 16, 81, 256, 625, 1296, 2401, 4096, 6561, 10000]
