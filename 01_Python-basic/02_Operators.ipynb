# %% [markdown]
# # 02 Operators Assessment
#
# Solve all questions below. Write your code under each question.

# %% [markdown]
# ## Question 1
# Given a=15 and b=4, print the result of +, -, *, /, //, %, and **.

# %%
a:int = 15 
b:int =4

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %% [markdown]
# ## Question 2
# Write expressions that evaluate to True using comparison operators.

# %%
print(2==2)
print(''!=0)
a=2
b=2
print(a is b )
# Out:
# True
# True
# True

# %% [markdown]
# ## Question 3
# Predict and then verify: (10 > 5) and (4 < 2), (10 > 5) or (4 < 2), not(10 > 5).

# %%
#false, true, false

(10 > 5) and (4 < 2), (10 > 5) or (4 < 2), not(10 > 5)
# Out:
# (False, True, False)

# %% [markdown]
# ## Question 4
# Find the output of: 5 & 3, 5 | 3, 5 ^ 3.

# %%
5 & 3, 5 | 3, 5 ^ 3
# Out:
# (1, 7, 6)

# %% [markdown]
# ## Question 5
# Without running first, predict the result of: 2 + 3 * 4 ** 2. Then verify.

# %%
#50

print(2 + 3 * 4 ** 2)
# Out:
# 50
