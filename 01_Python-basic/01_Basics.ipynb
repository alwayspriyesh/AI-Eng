# %% [markdown]
# # 01 Introduction and Basics Assessment
#
# Solve all questions below. Write your code under each question.

# %% [markdown]
# ## Question 1
# Create variables for your name, age, and dream role. Print them in a single formatted sentence.

# %%
name:str = "priyesh singh"
age : int = 13
dream:str = "i want to become AI engineer"

print(f"hi, my name is {name} & I'm {age}, and in future {dream}")
# Out:
# hi, my name is priyesh singh & I'm 13, and in future i want to become AI engineer

# %% [markdown]
# ## Question 2
# What is the difference between a keyword and an identifier? Give 3 examples of valid identifiers in code.

# %%
#Keywords are reserved words in Python that have predefined meanings and cannot be used as variable names. Identifiers are user-defined names used to identify variables, functions, classes, and other objects in a program.

#Examples of keywords: if, for, while.

#Examples of identifiers: age, student_name, calculate_sum.
age: int = 13 #inden

if (age==13): #keyword
    print("legal")
else:
    print("illegal")
# Out:
# legal

# %% [markdown]
# ## Question 3
# Create variables of type int, float, str, and bool. Print their types using type().

# %%
name:str = "pri"
age: int = 13
pie: float= 3.14159169
student:bool = True

print(type(name))
print(type(age))
print(type(pie))
print(type(student))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ## Question 4
# Swap the values of two variables without using a third variable.

# %%
a:int =11
b:int =13

a,b =b,a
print(f"before 11, 13 after swap {a}, {b}")
# Out:
# before 11, 13 after swap 13, 11

# %% [markdown]
# ## Question 5
# Predict the output first, then run:
# x=10
# y='10'
# print(type(x), type(y))

# %%
#int,str

x=10
y='10'
print(type(x), type(y))
# Out:
# <class 'int'> <class 'str'>
