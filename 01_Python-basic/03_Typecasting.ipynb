# %% [markdown]
# # 03 Typecasting Mutability Assessment
#
# Solve all questions below. Write your code under each question.

# %% [markdown]
# ## Question 1
# Convert the string '123' into int and float and print both.

# %%
string :str = '123'
print(int(string))
print(float(string))
# Out:
# 123
# 123.0

# %% [markdown]
# ## Question 2
# Take the value '45.8' and convert it to float, then int. What happens?

# %%
#gets convert to int 45

num:str = "45.8"
num2:float = float(num)
num3:int = int(num2)

print(num)
print(num2)
print(num3)
# Out:
# 45.8
# 45.8
# 45

# %% [markdown]
# ## Question 3
# Create a list and modify one element. Explain why this is allowed.

# %%
# because its mutable

list=[2,5,43,3]
list[1]= 69

print(list)
# Out:
# [2, 69, 43, 3]

# %% [markdown]
# ## Question 4
# Create a string and try to modify one character. What error do you get?

# %%
#TypeError: 'str' object does not support item assignment
string :str = 'pri'
string[0]='r'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 string :str = 'pri'
# ----> 2 string[0]='r'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ## Question 5
# Write a short comment explaining mutable vs immutable objects in your own words.

# %%
#mutable data type can be changed after declare, but immutable cannot
